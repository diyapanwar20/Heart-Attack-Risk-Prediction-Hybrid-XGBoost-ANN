# %% [markdown]
# # Heart Attack Prediction - Hybrid Model (XGBoost + ANN)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
## Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    roc_auc_score, accuracy_score, classification_report,
    roc_curve, auc, confusion_matrix,
    precision_recall_curve, average_precision_score
)

import xgboost as xgb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %% [markdown]
# ## Step 2: Load Dataset

# %%
csv_file = "Heart_disease_cleveland_new.csv"  # Replace with your CSV file
data = pd.read_csv(csv_file)         

# Rename columns if needed
columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach',
           'exang','oldpeak','slope','ca','thal','class']
if len(data.columns) == 14 and 'class' not in data.columns:
    data.columns = columns

# Handle missing values
data = data.replace('?', np.nan).dropna(axis=0)

# Convert numeric columns
data[columns] = data[columns].apply(pd.to_numeric)

# Binary target
data['class'] = (data['class'] > 0).astype(int)
print("Class distribution:\n", data['class'].value_counts())
# Out:
# Class distribution:
#  class
# 0    164
# 1    139
# Name: count, dtype: int64

# %% [markdown]
# ## Step 3: Feature Engineering

# %%
categorical_features = ['cp','restecg','slope','thal','ca']
X = pd.get_dummies(data.drop('class', axis=1), columns=categorical_features)
y = data['class']

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)
print("Training samples:", X_train.shape[0], "Testing samples:", X_test.shape[0])
# Out:
# Training samples: 242 Testing samples: 61

# %% [markdown]
# ## Step 4: Train XGBoost

# %%
scale_weight = (y_train == 0).sum() / (y_train == 1).sum()

xgb_model = xgb.XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    scale_pos_weight=scale_weight,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)
xgb_model.fit(X_train, y_train)

# XGBoost probabilities for ANN
xgb_train_pred = xgb_model.predict_proba(X_train)[:,1].reshape(-1,1)
xgb_test_pred = xgb_model.predict_proba(X_test)[:,1].reshape(-1,1)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 4.1: XGBoost Feature Importance

# %%
## Step 4.1: XGBoost Feature Importance
plt.figure(figsize=(10,6))
xgb.plot_importance(xgb_model, importance_type='weight', max_num_features=10,
                    height=0.5, show_values=False)
plt.title("XGBoost Feature Importance (Top 10)")
plt.show()

# Print top 10 features
importances = xgb_model.feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)
print("\nTop 10 Important Features from XGBoost:\n", feature_importance_df.head(10))
#thal_1 dominates → strong predictor for heart attack
# Out:
# Top 10 Important Features from XGBoost:
#      Feature  Importance
# 18   thal_1    0.403781
# 11     cp_3    0.083755
# 8      cp_0    0.066007
# 21     ca_0    0.061588
# 16  slope_1    0.037903
# 20   thal_3    0.036347
# 1       sex    0.032583
# 10     cp_2    0.029202
# 7   oldpeak    0.028314
# 9      cp_1    0.025825

# %% [markdown]
# ## Step 5: Build ANN (Hybrid)

# %%
X_train_ann = np.hstack([X_train, xgb_train_pred])
X_test_ann = np.hstack([X_test, xgb_test_pred])

ann_model = Sequential()
ann_model.add(Dense(32, input_dim=X_train_ann.shape[1], activation='relu'))
ann_model.add(Dropout(0.2))
ann_model.add(Dense(16, activation='relu'))
ann_model.add(Dense(1, activation='sigmoid'))

ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = ann_model.fit(
    X_train_ann, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4054 - loss: 0.8312 - val_accuracy: 0.4694 - val_loss: 0.7155
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6029 - loss: 0.6950 - val_accuracy: 0.5306 - val_loss: 0.6917
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6896 - loss: 0.6119 - val_accuracy: 0.7143 - val_loss: 0.6793
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7734 - loss: 0.5420 - val_accuracy: 0.7551 - val_loss: 0.6597
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8585 - loss: 0.4997 - val_accuracy: 0.7755 - val_loss: 0.6489
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8626 - loss: 0.4116 - val_accuracy: 0.7551 - val_loss: 0.6539
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8191 - loss: 0.4218 - val_accuracy: 0.7755 - val_loss: 0.6598
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8138 - loss: 0.3940 - val_accuracy: 0.7755 - val_loss: 0.6758
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8772 - loss: 0.3280 - val_accuracy: 0.7755 - val_loss: 0.6828
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8856 - loss: 0.3368 - val_accuracy: 0.7755 - val_loss: 0.6792
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9062 - loss: 0.2903 - val_accuracy: 0.7755 - val_loss: 0.6701
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8856 - loss: 0.2986 - val_accuracy: 0.7755 - val_loss: 0.6673
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9024 - loss: 0.2851 - val_accuracy: 0.7755 - val_loss: 0.6889
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9139 - loss: 0.2285 - val_accuracy: 0.7755 - val_loss: 0.6642
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8952 - loss: 0.2986 - val_accuracy: 0.7755 - val_loss: 0.6527
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9082 - loss: 0.2608 - val_accuracy: 0.7755 - val_loss: 0.6499
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8825 - loss: 0.2478 - val_accuracy: 0.7755 - val_loss: 0.6386
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9317 - loss: 0.2181 - val_accuracy: 0.7755 - val_loss: 0.6342
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9465 - loss: 0.2107 - val_accuracy: 0.7755 - val_loss: 0.6345
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9249 - loss: 0.2883 - val_accuracy: 0.7755 - val_loss: 0.6443
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9422 - loss: 0.2068 - val_accuracy: 0.7755 - val_loss: 0.6632
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9538 - loss: 0.2114 - val_accuracy: 0.7755 - val_loss: 0.6519
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9184 - loss: 0.2078 - val_accuracy: 0.7755 - val_loss: 0.6438
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9427 - loss: 0.1763 - val_accuracy: 0.7755 - val_loss: 0.6474
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9217 - loss: 0.1891 - val_accuracy: 0.7755 - val_loss: 0.6545
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9589 - loss: 0.1787 - val_accuracy: 0.7755 - val_loss: 0.6820
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9437 - loss: 0.2115 - val_accuracy: 0.7755 - val_loss: 0.6861
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9263 - loss: 0.1894 - val_accuracy: 0.7755 - val_loss: 0.6934
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9267 - loss: 0.2088 - val_accuracy: 0.7755 - val_loss: 0.6971
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9279 - loss: 0.1743 - val_accuracy: 0.7755 - val_loss: 0.6931
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9494 - loss: 0.1560 - val_accuracy: 0.7755 - val_loss: 0.6884
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9267 - loss: 0.1756 - val_accuracy: 0.7755 - val_loss: 0.7022
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9563 - loss: 0.1685 - val_accuracy: 0.7755 - val_loss: 0.7109
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9397 - loss: 0.1971 - val_accuracy: 0.7755 - val_loss: 0.7117
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9308 - loss: 0.1611 - val_accuracy: 0.7755 - val_loss: 0.6834
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9290 - loss: 0.1863 - val_accuracy: 0.7755 - val_loss: 0.6989
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9362 - loss: 0.1686 - val_accuracy: 0.7755 - val_loss: 0.7031
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9496 - loss: 0.1547 - val_accuracy: 0.7755 - val_loss: 0.7166
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9427 - loss: 0.1781 - val_accuracy: 0.7755 - val_loss: 0.7099
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9651 - loss: 0.1807 - val_accuracy: 0.7959 - val_loss: 0.7163
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9544 - loss: 0.1230 - val_accuracy: 0.7959 - val_loss: 0.6812
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1428 - val_accuracy: 0.7959 - val_loss: 0.7023
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9572 - loss: 0.1159 - val_accuracy: 0.7959 - val_loss: 0.7310
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9348 - loss: 0.1318 - val_accuracy: 0.7959 - val_loss: 0.7593
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.1084 - val_accuracy: 0.8163 - val_loss: 0.7606
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9551 - loss: 0.1095 - val_accuracy: 0.8163 - val_loss: 0.7610
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9717 - loss: 0.1119 - val_accuracy: 0.8163 - val_loss: 0.7717
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9519 - loss: 0.1094 - val_accuracy: 0.8163 - val_loss: 0.7622
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9697 - loss: 0.1217 - val_accuracy: 0.7959 - val_loss: 0.7562
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9503 - loss: 0.1099 - val_accuracy: 0.8163 - val_loss: 0.7542
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9782 - loss: 0.0953 - val_accuracy: 0.8163 - val_loss: 0.7968
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9853 - loss: 0.0879 - val_accuracy: 0.8163 - val_loss: 0.8028
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9416 - loss: 0.1066 - val_accuracy: 0.8163 - val_loss: 0.7826
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9819 - loss: 0.0681 - val_accuracy: 0.8367 - val_loss: 0.7629
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9561 - loss: 0.0892 - val_accuracy: 0.8367 - val_loss: 0.7635
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9565 - loss: 0.0892 - val_accuracy: 0.8367 - val_loss: 0.7659
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9480 - loss: 0.1212 - val_accuracy: 0.8367 - val_loss: 0.7368
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - loss: 0.0553 - val_accuracy: 0.8367 - val_loss: 0.7306
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9764 - loss: 0.0834 - val_accuracy: 0.8367 - val_loss: 0.7115
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9590 - loss: 0.0913 - val_accuracy: 0.8367 - val_loss: 0.6975
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9734 - loss: 0.0802 - val_accuracy: 0.8367 - val_loss: 0.6932
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9755 - loss: 0.0606 - val_accuracy: 0.8571 - val_loss: 0.6897
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9669 - loss: 0.1057 - val_accuracy: 0.8367 - val_loss: 0.6833
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9786 - loss: 0.0774 - val_accuracy: 0.8367 - val_loss: 0.6671
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9661 - loss: 0.0797 - val_accuracy: 0.8367 - val_loss: 0.7126
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9815 - loss: 0.0815 - val_accuracy: 0.8367 - val_loss: 0.6930
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9626 - loss: 0.0923 - val_accuracy: 0.8367 - val_loss: 0.6869
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9908 - loss: 0.0715 - val_accuracy: 0.8367 - val_loss: 0.6789
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.0843 - val_accuracy: 0.8367 - val_loss: 0.6864
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.0571 - val_accuracy: 0.8571 - val_loss: 0.6834
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9801 - loss: 0.0608 - val_accuracy: 0.8571 - val_loss: 0.6887
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9821 - loss: 0.0676 - val_accuracy: 0.8571 - val_loss: 0.7318
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9818 - loss: 0.0466 - val_accuracy: 0.8571 - val_loss: 0.7230
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0440 - val_accuracy: 0.8571 - val_loss: 0.7015
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9757 - loss: 0.0615 - val_accuracy: 0.8571 - val_loss: 0.6881
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9693 - loss: 0.0586 - val_accuracy: 0.8571 - val_loss: 0.6842
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0301 - val_accuracy: 0.8571 - val_loss: 0.6819
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0602 - val_accuracy: 0.8571 - val_loss: 0.6665
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0388 - val_accuracy: 0.8571 - val_loss: 0.6485
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9910 - loss: 0.0374 - val_accuracy: 0.8571 - val_loss: 0.6317
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0387 - val_accuracy: 0.8571 - val_loss: 0.6294
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9834 - loss: 0.0386 - val_accuracy: 0.8571 - val_loss: 0.6348
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.0413 - val_accuracy: 0.8571 - val_loss: 0.6267
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9936 - loss: 0.0289 - val_accuracy: 0.8367 - val_loss: 0.6150
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9891 - loss: 0.0444 - val_accuracy: 0.8367 - val_loss: 0.6059
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9820 - loss: 0.0540 - val_accuracy: 0.8367 - val_loss: 0.5983
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9899 - loss: 0.0293 - val_accuracy: 0.8367 - val_loss: 0.5840
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.8367 - val_loss: 0.5774
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9910 - loss: 0.0377 - val_accuracy: 0.8571 - val_loss: 0.5890
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - loss: 0.0224 - val_accuracy: 0.8571 - val_loss: 0.6010
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9970 - loss: 0.0362 - val_accuracy: 0.8571 - val_loss: 0.5925
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0273 - val_accuracy: 0.8571 - val_loss: 0.5511
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.0222 - val_accuracy: 0.8776 - val_loss: 0.5275
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9910 - loss: 0.0483 - val_accuracy: 0.8776 - val_loss: 0.5228
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9975 - loss: 0.0301 - val_accuracy: 0.8776 - val_loss: 0.5672
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0231 - val_accuracy: 0.8776 - val_loss: 0.6003
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0338 - val_accuracy: 0.8776 - val_loss: 0.6097
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9753 - loss: 0.0495 - val_accuracy: 0.8776 - val_loss: 0.5989
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9854 - loss: 0.0315 - val_accuracy: 0.8776 - val_loss: 0.6056
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9854 - loss: 0.0230 - val_accuracy: 0.8776 - val_loss: 0.6253

# %% [markdown]
# ## Step 5.1: ANN Training History

# %%
## Step 5.1: ANN Training History
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('ANN Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend() 
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('ANN Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show(

# %% [markdown]
# ## Step 6: Evaluate Hybrid Model

# %%
## Step 6: Evaluate Hybrid Model
ann_probs = ann_model.predict(X_test_ann)
ann_classes = (ann_probs > 0.5).astype(int)

accuracy = accuracy_score(y_test, ann_classes)
auc_score = roc_auc_score(y_test, ann_probs)

print("Hybrid Model Accuracy:", accuracy)
print("Hybrid Model AUC-ROC:", auc_score)
print("\nClassification Report:\n", classification_report(y_test, ann_classes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## Step 6: Evaluate Hybrid Model
# ----> 2 ann_probs = ann_model.predict(X_test_ann)
#       3 ann_classes = (ann_probs > 0.5).astype(int)
#       5 accuracy = accuracy_score(y_test, ann_classes)
#
# NameError: name 'ann_model' is not defined

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, ann_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0,1],[0,1], color='navy', lw=2, linestyle='--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Hybrid Heart Attack Prediction')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Step 6.1: Confusion Matrix

# %%
cm = confusion_matrix(y_test, ann_classes)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['No Heart Attack','Heart Attack'],
            yticklabels=['No Heart Attack','Heart Attack'])
plt.title("Confusion Matrix - Hybrid Model")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Step 6.2: Precision-Recall Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test, ann_probs)
ap = average_precision_score(y_test, ann_probs)

plt.figure(figsize=(8,6))
plt.plot(recall, precision, label=f'AP = {ap:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve - Hybrid Model')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 7: Predict New Patient

# %%
new_patient = pd.DataFrame([{
    'age': 60, 'sex': 0, 'cp': 2, 'trestbps': 130, 'chol': 210,
    'fbs': 1, 'restecg': 0, 'thalach': 165, 'exang': 1,
    'oldpeak': 1.5, 'slope': 1, 'ca': 1, 'thal': 2
}])

# One-hot encode & align with training features
new_patient = pd.get_dummies(new_patient, columns=categorical_features)
missing_cols = set(X.columns) - set(new_patient.columns)
for c in missing_cols:
    new_patient[c] = 0
new_patient = new_patient[X.columns]

# Scale
new_patient_scaled = scaler.transform(new_patient)

# XGBoost probability
xgb_prob_new = xgb_model.predict_proba(new_patient_scaled)[:,1].reshape(-1,1)

# ANN prediction
new_input_ann = np.hstack([new_patient_scaled, xgb_prob_new])
pred_class = (ann_model.predict(new_input_ann) > 0.5).astype(int)[0][0]
pred_prob = ann_model.predict(new_input_ann)[0][0]

print("Predicted Class (0 = No Heart Attack, 1 = Heart Attack):", pred_class)
print(f"Probability of Heart Attack: {pred_prob:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted Class (0 = No Heart Attack, 1 = Heart Attack): 1
# Probability of Heart Attack: 0.81

# %%
import joblib

# Save
joblib.dump(scaler, "scaler.pkl")
joblib.dump(xgb_model, "xgb_model.pkl")
ann_model.save("ann_model.h5")

# Reload later
scaler = joblib.load("scaler.pkl")
xgb_model = joblib.load("xgb_model.pkl")
ann_model = tf.keras.models.load_model("ann_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
